# %% [markdown]
# ##Operators

# %% [markdown]
# ### Addiction

# %%
2+7
# Out:
# 9

# %% [markdown]
# ### Subtraction

# %%
10-7
# Out:
# 3

# %% [markdown]
# ### Multiplication

# %%
2*3
# Out:
# 6

# %% [markdown]
# ### String Multiplication

# %%
'Data' * 3
# Out:
# 'DataDataData'

# %% [markdown]
# ### Division

# %%
50/10
# Out:
# 5.0

# %% [markdown]
# ### Exponentiation

# %%
2**3
# Out:
# 8

# %% [markdown]
# ### Root

# %%
9**0.5
# Out:
# 3.0

# %% [markdown]
# ### Floor Division

# %%
7//3
# Out:
# 2

# %% [markdown]
# ### Modulo

# %%
7%3
# Out:
# 1

# %% [markdown]
# ### Less than and less than aequal to

# %%
2 < 4
# Out:
# True

# %%
4 <= 3
# Out:
# False

# %% [markdown]
# ### More than and more than equal

# %%
35 > 4
# Out:
# True

# %%
35 >= 34
# Out:
# True

# %% [markdown]
# ### Equal to

# %%
4 == 5
# Out:
# False

# %%
3 == 3
# Out:
# True

# %% [markdown]
# ### Not Equal to

# %%
3 != 3
# Out:
# False

# %%
3 !=4
# Out:
# True

# %% [markdown]
# You can use string too in function

# %%
a = 'Keynes'

# %%
b = ' keynes'

# %%
a == b

# different capital letters can make a difference to the function
# Out:
# False

# %% [markdown]
# #Boolean Not
#
# - if x is true, the function will return false
# - if x evaluates to false, the function returns true

# %%
x = False

# %%
not x
# Out:
# True

# %% [markdown]
# #and (Boolean AND )
#
# x and y will return false if x is false, or the function will return y

# %%
a = True

# %%
b = False

# %%
a and b
# Out:
# False

# %%
a = True

# %%
b = True

# %%
a and b
# Out:
# True

# %% [markdown]
# #or  (Boolean OR)
#
# if x is true then the function will return true or the function will return the value of y

# %%
a = True

# %%
b = False

# %%
a or b
# Out:
# True

# %%
a = False

# %%
b = False

# %%
a or b
# Out:
# False

# %% [markdown]
# ###Short way to write in Python

# %%
a = 10

# %%
a = a * 2

# %%
#or
a*=2

# %%
print(a)
# Out:
# 80

# %%
#apply with other operations
a -= 10

# %%
print (a)
# Out:
# 70

# %% [markdown]
# ### Math Writing

# %%
1 + 2 *5 + 4 - 2 /4 *2 +1 **2
# Out:
# 15.0

# %%
1 + (2*5) + 4 - ((2/4)*2)+ (1**2)
# Out:
# 15.0
