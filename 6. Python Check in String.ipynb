# %% [markdown]
# # Python Check in String
# In the string checking category it checks for the boolean of a string. When it meets the conditions then the value will be True, if the string does not meet the conditions then the value will be False
#
# ### isupper()
# isupper() method returns True if all letters in the string are uppercase, and returns False if only one of the letters is lowercase in the string.

# %%
a ="DATA SCIENCE"

# %%
a.isupper()
# Out:
# True

# %%
a ="Data Science"

# %%
a.isupper()
# Out:
# False

# %% [markdown]
# ## islower()
# islower() method returns True if all letters in the string are lowercase, and returns False if only one letter is capitalized in the string.

# %%
a = "Data Engineer"

# %%
a.islower()
# Out:
# False

# %%
a = "data analysis"

# %%
a.islower()
# Out:
# True

# %% [markdown]
# We can also perform operations on the result of the operation (chain of method)

# %%
print("Data".upper().lower())
# Out:
# data

# %%
print("Data".lower().upper())
# Out:
# DATA

# %%
print("Data".lower().upper().isupper())
# Out:
# True

# %%
print("DATA".upper().lower().isupper())
# Out:
# False

# %% [markdown]
# ## isalpha()
# Returns True if all characters in the string are letters of the alphabet. If not then False

# %%
print("Data".isalpha())
# Out:
# True

# %%
print("5434".isalpha())
# Out:
# False

# %% [markdown]
# ## isalnum()
# Returns True value if all characters in the string are alphanumeric letters i.e. letters only or numbers only or both. If not then False

# %%
print("Data20199".isalnum())
# Out:
# True

# %%
print("Data".isalnum())
# Out:
# True

# %%
print("2%".isalnum())
# Out:
# False

# %%
print("40".isalnum())
# Out:
# True

# %% [markdown]
# ## isdecimal()
# Returns True if the character in the string contains only numbers/numerics. Otherwise it will return False

# %%
print("Dataset2022".isdecimal())
# Out:
# False

# %%
print("21022022".isdecimal())
# Out:
# True

# %% [markdown]
# ## ispace()
# Returns true if the string contains only whitespace characters, such as spaces, tabs, newlines or other whitespace characters. If not then false

# %%
print("\t".isspace())
# Out:
# True

# %%
print("\n Oke".isspace())
# Out:
# False

# %% [markdown]
# ## istitle()
# Returns true if the string contains a capital letter in every word and continues with lowercase letters. If not then False

# %%
print("Data Science".istitle())
# Out:
# True

# %%
print("Data science".istitle())
# Out:
# False
