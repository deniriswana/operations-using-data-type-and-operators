# %% [markdown]
# #Dynamic Typing
# Python is a dynamically typed language. When declaring a variable in Python, you don’t specify a type for it, which means the Python interpreter does type checking only as code runs, and the type of a variable is allowed to change over its lifetime. Here a couple of dynamic typing examples:

# %% [markdown]
# ### type()
#
# Type() is one of the Python's built-in functions that can find the class type of the variable given as input.

# %%
a = 20
type(a)
# Out:
# int

# %% [markdown]
# ### len()
# Returns the length of an object. For example, it can return the number of character in a string include white space, or return the number of element in list/set data type. It can be used with many different data types. However, not all data types are valid arguments for len().

# %%
a = "Data Science"
len(a)
# Out:
# 12

# %%
b = 8
len(b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-9dd228f947b9> in <module>()
#       1 b = 10
# ----> 2 len(b)
#
# TypeError: object of type 'int' has no len()
